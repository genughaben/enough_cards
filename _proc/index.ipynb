# %% [raw]
# ---
# description: A sample of how to create a deck of cards lib using nbdev
# output-file: index.html
# title: enough_cards
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install enough_cards
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# The lib [`Card`](https://genughaben.github.io/enough_cards/card.html#card) helps to create and compare playing cards

# %%
Card(1,2)
# Out:
# ♠️2

# %%
Card(1,2) < Card(1,1)
# Out:
# False
